# %%
#Header Files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=1
b=5
c=a+b
c
# Out:
# 6

# %%
#importing the all ready exist excel file
path="Visadataset.csv"#path of file
pd.read_csv(path)#read the file
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#import 2 nd all ready exist file
path="bank.csv" 
pd.read_csv(path)
#pd.read_csv(path,sep=';',header=None)
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
#import 2 nd all ready exist file
path="bank.csv" 
pd.read_csv(path,sep=';')
#pd.read_csv(path,sep=';',header=None)#to solve above Display problem give sep
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
#import 2 nd all ready exist file
path="bank.csv" 
pd.read_csv(path,sep=';',header=None)#to avoid header of column give header=none
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %%
#create list to create DataFrame
name=['Ramesh','Santosh','Mahesh']
age=[30,40,35]
name,age
# Out:
# (['Ramesh', 'Santosh', 'Mahesh'], [30, 40, 35])

# %%
#Save list to the DataFrame
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0   Ramesh  30
# 1  Santosh  40
# 2   Mahesh  35

# %%
#Add Column Name to Dataframe
data=zip(name,age)
cols=['Name','Age']
pd.DataFrame(data,columns=cols)
# Out:
#       Name  Age
# 0   Ramesh   30
# 1  Santosh   40
# 2   Mahesh   35

# %%
#Direct Value Passing to the Dataframe Parameters
#data=zip(name,age)
#cols=['Name','Age']
pd.DataFrame(zip(name,age),columns=['Name','Age'])
# Out:
#       Name  Age
# 0   Ramesh   30
# 1  Santosh   40
# 2   Mahesh   35

# %%
#Passing index to the Rows
ind=['A','B','C']
pd.DataFrame(zip(name,age),columns=['Name','Age'],index=ind)
# Out:
#       Name  Age
# A   Ramesh   30
# B  Santosh   40
# C   Mahesh   35

# %%
#Adding New Column to the Dataframe
city_nm=['Hyd','pune','Begaluru']
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
df['City']=city_nm
df
# Out:
#       Name  Age      City
# A   Ramesh   30       Hyd
# B  Santosh   40      pune
# C   Mahesh   35  Begaluru

# %%
#Updateting the Dataframe with existing Data
ind=['A','B','C']
df=pd.DataFrame(zip(name,age),columns=['Name','Age'],index=ind)
df['Name']=['Reshma','Shamali','Mahadevi']
df
# Out:
#        Name  Age
# A    Reshma   30
# B   Shamali   40
# C  Mahadevi   35

# %%
#Deleting the Dataframe column
city_nm=['Hyd','pune','Begaluru']
data=zip(name,age)
#cols=['Name','Age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=['Name','Age'],index=ind)
df['City']=city_nm
df['Name']=['Reshma','Shamali','Mahadevi']
df.drop('City',axis=1,inplace=True)
#inplace=True Overwrite the dataframe inplace=false create new Dataframe
df
# Out:
#        Name  Age
# A    Reshma   30
# B   Shamali   40
# C  Mahadevi   35

# %%
#Deleting The Row of the Dataframe make axis=0 to delete row 
#maintion the row index to delete perticular row
city_nm=['Hyd','pune','Begaluru']
ind=['A','B','C']
df1=pd.DataFrame(zip(name,age),columns=['Name','Age'],index=ind)
df1['City']=city_nm
df1['Name']=['Reshma','Shamali','Mahadevi']
df1.drop('C',axis=0,inplace=True)#c is the index of row 
df1
# Out:
#       Name  Age  City
# A   Reshma   30   Hyd
# B  Shamali   40  pune

# %%
#Creating excel file to store df1 dataframe
df1.to_csv("output.csv")
pd.read_csv("output.csv")#read stored Data
#while saving a,b index is saying extra column so you have to give index=false
# Out:
#   Unnamed: 0     Name  Age  City
# 0          A   Reshma   30   Hyd
# 1          B  Shamali   40  pune

# %%
#To avoid  unmaned Column set index as False
df1.to_csv("output.csv",index=False)
pd.read_csv("output.csv")
#while saving a,b index is saying extra column so you have to give index=false
# Out:
#       Name  Age  City
# 0   Reshma   30   Hyd
# 1  Shamali   40  pune

# %%
#Create DataFrame Using Dictionary
d1={"Name":['Reshma','Shamali','Mahadevi','Santosh','Mayank','Maurya'],
    "Age":[35,30,30,40,10,5]
   }
#cols=['Name','Age']
ind=['A','B','C','D','E','F']
pd.DataFrame(d1,index=ind)#No need to columns Name and Zip
# Out:
#        Name  Age
# A    Reshma   35
# B   Shamali   30
# C  Mahadevi   30
# D   Santosh   40
# E    Mayank   10
# F    Maurya    5

# %%
#Updateting Dataframe with new column
dic=pd.DataFrame(d1)
dic["City"]=['Hyd','Begloru','Pune','Mumbai','Kalkata','Chainai']
dic
# Out:
#        Name  Age     City
# 0    Reshma   35      Hyd
# 1   Shamali   30  Begloru
# 2  Mahadevi   30     Pune
# 3   Santosh   40   Mumbai
# 4    Mayank   10  Kalkata
# 5    Maurya    5  Chainai

# %%
dic=pd.DataFrame(d1)
#pd(d1,d2)
print(dic)
print("\n______________After Upadation of Name Column_________________")
dic['Name']=['Santosh','Somanath','Raghav','Rahul','sunil','Rutuja']
dic
# Out:
#        Name  Age
# 0    Reshma   35
# 1   Shamali   30
# 2  Mahadevi   30
# 3   Santosh   40
# 4    Mayank   10
# 5    Maurya    5
#
# ______________After Upadation of Name Column_________________
#        Name  Age
# 0   Santosh   35
# 1  Somanath   30
# 2    Raghav   30
# 3     Rahul   40
# 4     sunil   10
# 5    Rutuja    5

# %%
dic=pd.DataFrame(d1)
dic["City"]=['Hyd','Begloru','Pune','Mumbai','Kalkata','Chainai']
print(dic)

print("___________________-After drop city Column______________________________")

dic.drop("City",axis=1,inplace=True)
dic
# Out:
#        Name  Age     City
# 0    Reshma   35      Hyd
# 1   Shamali   30  Begloru
# 2  Mahadevi   30     Pune
# 3   Santosh   40   Mumbai
# 4    Mayank   10  Kalkata
# 5    Maurya    5  Chainai
# ___________________-After drop city Column______________________________
#        Name  Age
# 0    Reshma   35
# 1   Shamali   30
# 2  Mahadevi   30
# 3   Santosh   40
# 4    Mayank   10
# 5    Maurya    5

# %%
#Drop Row of Dataframe
#ind=['A','B','C','D','E','F']
dic=pd.DataFrame(d1)
print(dic)
print("________________-___________After the  Row Drop___________________________________")
dic.drop(1,axis=0,inplace=True)
dic
# Out:
#        Name  Age
# 0    Reshma   35
# 1   Shamali   30
# 2  Mahadevi   30
# 3   Santosh   40
# 4    Mayank   10
# 5    Maurya    5
# ________________-___________After the  Row Drop___________________________________
#        Name  Age
# 0    Reshma   35
# 2  Mahadevi   30
# 3   Santosh   40
# 4    Mayank   10
# 5    Maurya    5

# %%
#Save Dataframe
dic.to_csv("DicDataFrame.csv",index=False)
pd.read_csv("DicDataFrame.csv")
# Out:
#        Name  Age
# 0    Reshma   35
# 1  Mahadevi   30
# 2   Santosh   40
# 3    Mayank   10
# 4    Maurya    5

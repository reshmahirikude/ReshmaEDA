# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path='Visadataset.csv'
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
q1=np.percentile(visa_df['prevailing_wage'],25)
q2=np.percentile(visa_df['prevailing_wage'],50)
q3=np.percentile(visa_df['prevailing_wage'],75)
iqr=q1-q3
lb=q1-1.5*iqr
ub=q3-1.5*iqr
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
condition=c1|c2
outliers_df=visa_df[condition]
print("------------------Outliers dataframe_____________________________\n")
outliers_df
# Out:
# ------------------Outliers dataframe_____________________________
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 5                         N             2339         2012
# ...                     ...              ...          ...
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 5                    South       78252.1400         Year                  Y
# ...                    ...              ...          ...                ...
# 25474            Northeast       51104.7800         Year                  Y
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 5       Certified
# ...           ...
# 25474   Certified
# 25475   Certified
# 25476   Certified
# 25478   Certified
# 25479   Certified
#
# [23734 rows x 12 columns]

# %%
list1=[]
q1=np.percentile(visa_df['prevailing_wage'],25)
q2=np.percentile(visa_df['prevailing_wage'],50)
q3=np.percentile(visa_df['prevailing_wage'],75)
iqr=q1-q3
lb=q1-1.5*iqr
ub=q3+1.5*iqr
median=visa_df['prevailing_wage'].median()
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        list1.append(median)
    else:
        list1.append(i)
visa_df['prevailing_wage_new']=list1
visa_df['prevailing_wage_new']
# Out:
# 0        70308.21
# 1        70308.21
# 2        70308.21
# 3        70308.21
# 4        70308.21
#            ...
# 25475    70308.21
# 25476    70308.21
# 25477    70308.21
# 25478    70308.21
# 25479    70308.21
# Name: prevailing_wage_new, Length: 25480, dtype: float64

# %%
plt.boxplot(visa_df['prevailing_wage_new'])
plt.show()

# %%
#without np.where
list1=[]
dic1={'Name':['A','B','C','D'],
        'Age':[1,2,3,4]}
dict1_df=pd.DataFrame(dic1)
#i want to replace age which is >2 other which keep as it is
for i in dic1['Age']:
    if i>2:
        list1.append(100)
    else:
        list1.append(i)
list1
# Out:
# [1, 2, 100, 100]

# %%
#np.where
dict1={'Name':['A','B','C','D'],
 'Num':[1,2,3,4]}
d=pd.DataFrame(dict1)
d
d['Num']>2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: Num, dtype: bool

# %%
l=np.where(d['Num']>2,100,d['Num'])
d['Num']=l
d
# Out:
#   Name  Num
# 0    A    1
# 1    B    2
# 2    C  100
# 3    D  100

# %%
#np.where takes 3 argu con,true,false value
d={}
q1=np.percentile(visa_df['prevailing_wage'],25)
q2=np.percentile(visa_df['prevailing_wage'],50)
q3=np.percentile(visa_df['prevailing_wage'],75)
iqr=q1-q3
lb=q1-1.5*iqr
ub=q3-1.5*iqr
median1=visa_df['prevailing_wage'].median()
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
cond=c1|c2
t=median1
f=visa_df['prevailing_wage']
visa_df['prevailing_wage_npwhere']=np.where(cond,t,f)
visa_df['prevailing_wage_npwhere']
# Out:
# 0        70308.21
# 1        70308.21
# 2        70308.21
# 3        70308.21
# 4        70308.21
#            ...
# 25475    70308.21
# 25476    70308.21
# 25477    70308.21
# 25478    70308.21
# 25479    70308.21
# Name: prevailing_wage_npwhere, Length: 25480, dtype: float64

# %%
plt.boxplot(visa_df['prevailing_wage'])
plt.show()

# %%
#####------------- Step-1------###########
Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)
#####------------- Step-2------###########
IQR=Q3-Q1
#####------------- Step-3------###########
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
median=visa_df['prevailing_wage'].median()
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
con=c1|c2
t=median
f=visa_df['prevailing_wage']
visa_df['prevailing_wage']=np.where(con,t,f)
plt.boxplot(visa_df['prevailing_wage'])
plt.show()
